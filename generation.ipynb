# %% [markdown]
# <a href="https://colab.research.google.com/github/LuckyHorseshoe-chan/DatasetAnalysis/blob/main/generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class lab:
  def __init__(self, id, name, date, specialization, owner, income, expense, branches):
    self.id = id
    self.name = name
    self.date = date
    self.specialization = specialization
    self.owner = owner
    self.income = income
    self.expense = expense
    self.branches = branches
class protein:
  def __init__(self, id, name, kind, func, presence):
    self.id = id
    self.name = name
    self.kind = kind
    self.func = func
    self.presence = presence
class equipment:
  def __init__(self, id, name, destin, okay):
    self.id = id
    self.name = name
    self.destin = destin
    self.okay = okay

# %%
import random

lab1 = lab("1", "BostonGene", "04-05-1999", "Молекулярная биология", "Мария Добычина", "200000", "50000", "3")
lab2 = lab("2", "BioCad", "11-07-1996", "Молекулярная биология", "Дмитрий Морозов", "300000", "120000", "2")
lab3 = lab("3", "Сколково", "04-05-1985", "Биохимия", "Виктор Вексельберг", "250000", "150000", "3")
labs = [lab1, lab2, lab3]
protein1 = protein("1", "гликопротеины", "сложный", "гормон", "1")
protein2 = protein("2", "гликопротеины", "сложный", "гормон", "0")
protein3 = protein("3", "липопротеины", "сложный", "транспорт", "1")
protein4 = protein("4", "липопротеины", "сложный", "транспорт", "0")
protein5 = protein("5", "фосфопротеины", "сложный", "регулирование", "1")
protein6 = protein("6", "фосфопротеины", "сложный", "регулирование", "0")
protein7 = protein("7", "гистоны", "простой", "упаковка нитей ДНК", "1")
protein8 = protein("8", "гистоны", "простой", "упаковка нитей ДНК", "0")
protein9 = protein("9", "хромопротеиды", "сложный", "аккумулирование энергии", "1")
protein10 = protein("10", "хромопротеиды", "сложный", "аккумулирование энергии", "0")
protein11 = protein("11", "альбумины", "простой", "траспорт", "1")
protein12 = protein("12", "альбумины", "простой", "транспорт", "0")
proteins = [protein1, protein2, protein3, protein4, protein5, protein6, protein7, protein8, protein9, protein10, protein11, protein12]
licenses = ["GNU GPL", "GPLv3", "Berkeley", "BSD", "Boost", "CeCill", "Cryptix", "eCos", "Freetype", "iMatix"]
owners = ["Свежелов", "Фрешер", "БонФреш", "А-Свеж", "Новичок", "Ценовик", "Снежанс", "Авоська", "Ажур", "Пользолов", "Супер-толк", "АльтерМаг", "УмФорма", "Рационик", "Биомаг", "Кулёк", "Подкова", "Полюс"]
suppliers = ["Лавка", "Сова", "Скат", "Свекла", "Дилижанс", "Лилия", "Ширма", "Ленист", "Глобум", "Кашира", "Нембус", "Альферац", "Вега", "Мега", "Антарес", "Хобот", "Бульба", "БонФреш", "Подкова", "АмФорма"]
employees = ["стажёр-исследователь", "младший научный сотрудник", "научный сотрудник", "старший научный сотрудник", "ведущий научный сотрудник", "главный научный сотрудник"]
equip1 = equipment("1", "Гелиевый реконденсатор сверхпроводящего магнита", "Реконденсация", "1")
equip2 = equipment("2", "Гелиевый реконденсатор сверхпроводящего магнита", "Реконденсация", "0")
equip3 = equipment("3", "Полуавтоматическая зондовая станция", "Прецизионное позиционирование", "1")
equip4 = equipment("4", "Полуавтоматическая зондовая станция", "Прецизионное позиционирование", "0")
equip5 = equipment("5", "Многофункциональный сверхширокополосный измерительный комплекс параметров материалов", "Для исследований свойств нано- метаматериалов нелинейных оптических сред полимеров и нанобиосистем", "1")
equip6 = equipment("6", "Многофункциональный сверхширокополосный измерительный комплекс параметров материалов", "Для исследований свойств нано- метаматериалов нелинейных оптических сред полимеров и нанобиосистем", "0")
equip7 = equipment("7", "Система для осаждения алмазных пленок", "Осаждение алмазных пленок", "1")
equip8 = equipment("8", "Система для осаждения алмазных пленок", "Осаждение алмазных пленок", "0")
equip9 = equipment("9", "Исследовательская установка", "Нанесение ЛЦУ пленок и различных гетероструктур", "1")
equip10 = equipment("10", "Исследовательская установка", "Нанесение ЛЦУ пленок и различных гетероструктур", "0")
equip11 = equipment("11", "Система для измерения физических свойств PPMS-9", "Измерение физических свойств PPMS-9", "1")
equip12 = equipment("12", "Система для измерения физических свойств PPMS-9", "Измерение физических свойств PPMS-9", "0")
equip13 = equipment("13", "	Электронно-зондовый микроанализатор JXA-8230", "Структурный анализ", "1")
equip14 = equipment("14", "	Электронно-зондовый микроанализатор JXA-8230", "Структурный анализ", "0")
equip15 = equipment("15", "Мессбауэровский спектрометр", "Структурный анализ", "1")
equip16 = equipment("16", "Мессбауэровский спектрометр", "Структурный анализ", "0")
equip17 = equipment("17", "Конфокальный КР микроскоп", "Структурный анализ", "1")
equip18 = equipment("18", "Конфокальный КР микроскоп", "Структурный анализ", "0")
equip19 = equipment("19", "Когерентный томографический трехчастотный комплекс приема спутниковых сигналов", "Прием спутниковых сигналов", "1")
equip20 = equipment("20", "Когерентный томографический трехчастотный комплекс приема спутниковых сигналов", "Прием спутниковых сигналов", "0")
equip21 = equipment("21", "Радиотомографический комплекс для исследований ионосферы и ближнего космоса", "Исследования ионосферы и ближнего космоса", "1")
equip22 = equipment("22", "Радиотомографический комплекс для исследований ионосферы и ближнего космоса", "Исследования ионосферы и ближнего космоса", "0")
equip = [equip1, equip2, equip3, equip4, equip5, equip6, equip7, equip8, equip9, equip10, equip11, equip12, equip13, equip14, equip15, equip16, equip17, equip18, equip19, equip20, equip21, equip22]
medicines1 = ["Вертекс", "Хай", "", "Чабреца", "КУ-Таб", "ОД", "", "Форте", "Цин", "Юниор","", "Сан", "Плюс", "Минус", "Агри", "Коли", "Л52", "Акри", "П", "Канон", "Ретард", ""]
medicines2 = ["Бавенсио", "Вагисепт", "Габапентин", "Дабловир", "Кабецин", "Пайлекс", "Рабепразол", "Кром", "Халиксол", "Трава", "Эбермин", "Таксакад", "Жанин", "Заласта", "Лавудин", "Убистезин", "Цевикал", "Рабелок", "Иардол", "Йогексол"]
f = open('labs.txt', 'w')
f.write("ID_lab   ID_medicine   ID_equip   ID_license   ID_employee   Название   Дата_основания   Специализация   Владелец   Годовые_доходы   Годовые_расходы   Количество_филиалов\n")
for i in range(500):
  id_med = random.randint(1, 1200)
  id_equip = random.randint(1, 500)
  id_lic = random.randint(1, 500)
  id_empl = random.randint(1, 1200)
  f.write("1" + ',' + str(id_med) + ',' + str(id_equip) + ',' + str(id_lic) + ',' + str(id_empl) + ',' + lab1.name + ',' + lab1.date + ',' 
          + lab1.specialization + ',' + lab1.owner + ',' + lab1.income + ',' + lab1.expense + ',' + lab1.branches + '\n')
for i in range(500):
  id_med = random.randint(1, 1200)
  id_equip = random.randint(1, 500)
  id_lic = random.randint(1, 500)
  id_empl = random.randint(1, 1200)
  f.write("2" + ',' + str(id_med) + ',' + str(id_equip) + ',' + str(id_lic) + ',' + str(id_empl) + ',' + lab2.name + ',' + lab2.date + ',' 
          + lab2.specialization + ',' + lab2.owner + ',' + lab2.income + ',' + lab2.expense + ',' + lab2.branches + '\n')
for i in range(500):
  id_med = random.randint(1, 1200)
  id_equip = random.randint(1, 500)
  id_lic = random.randint(1, 500)
  id_empl = random.randint(1, 1200)
  f.write("3" + ',' + str(id_med) + ',' + str(id_equip) + ',' + str(id_lic) + ',' + str(id_empl) + ',' + lab3.name + ',' + lab3.date + ',' 
          + lab3.specialization + ',' + lab3.owner + ',' + lab3.income + ',' + lab3.expense + ',' + lab3.branches + '\n')
f.close()
f = open('medicines.txt', 'w')
f.write("ID_medicine   ID_protein   Название   Порция\n")
for i in range(1200):
  id_prot = random.randint(1, len(proteins))
  med1 = random.randint(0, len(medicines1) - 1)
  med2 = random.randint(0, len(medicines2) - 1)
  f.write(str(i + 1) + ',' + str(id_prot) + ',' + medicines1[med1] + ' ' + medicines2[med2] + ',' + str(random.randrange(20, 500, 10)) + '\n')
f.close()
f = open('proteins.txt', 'w')
f.write("ID_protein   Название   Вид   Функция   Есть_в_наличии\n")
for protein in proteins:
  f.write(protein.id + ',' + protein.name + ',' + protein.kind + ',' + protein.func + ',' + protein.presence + '\n')
f.close()
f = open('employees.txt', 'w')
f.write("ID_employee   Пол   Возраст   Стаж   Должность   Зарплата\n")
sex = ["жен", "муж"]
for i in range(1200):
  age = random.randint(21, 90)
  expir = random.randint(0, 70)
  money = random.randrange(20000, 200000, 10000)
  pos = random.randint(0, len(employees) - 1)
  s = random.randint(0, 1)
  f.write(str(i + 1) + ',' + sex[s] + ',' + str(age)  + ',' + str(expir) + ',' + employees[pos] + ',' + str(money) + '\n')
f.close()
f = open('licenses.txt', 'w')
f.write("ID_license   ID_company   Название   Оборудование\n")
for i in range(500):
  id_comp = random.randint(1, len(owners))
  name = random.randint(0, len(licenses) - 1)
  eq = random.randint(0, len(equip) - 1)
  f.write(str(i+1) + ',' + str(id_comp)  + ',' + licenses[name] + ','  + equip[eq].name + '\n')
f.close()
f = open('owners.txt', 'w')
countries = ["Россия", "Япония", "США", "Германия", "Китай"]
f.write("ID_company   Название   Страна\n")
for i in range(len(owners)):
  if(i % 2 == 0):
    c = random.randint(0, len(countries) - 1)
  f.write(str(i+1) + ',' + owners[i] + ',' + countries[c] + '\n')
f.close()
f = open('equipment.txt', 'w')
f.write("ID_equip   ID_supplier   Название   Назначение   Исправно\n")
for i in range(500):
  sup = random.randint(1, len(suppliers))
  eq = random.randint(0, len(equip) - 1)
  f.write(str(i + 1) + ',' +  str(sup) + ',' + equip[eq].name + ',' + equip[eq].destin + ',' + equip[eq].okay + '\n')
f.close()
f = open('suppliers.txt', 'w')
f.write("ID_supplier   Название\n")
for i in range(len(suppliers)):
  f.write(str(i + 1) + ',' + suppliers[i] + '\n')
f.close()
